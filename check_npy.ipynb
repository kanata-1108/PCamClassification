# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train = np.load('/project/data/camelyonpatch_level_2_split_train_x.npy')
y_train = np.load('/project/data/camelyonpatch_level_2_split_train_y.npy')
x_valid = np.load('/project/data/camelyonpatch_level_2_split_valid_x.npy')
y_valid = np.load('/project/data/camelyonpatch_level_2_split_valid_y.npy')
x_test = np.load('/project/data/camelyonpatch_level_2_split_test_x.npy')

# %%
print(x_train.shape)
print(y_train.shape)
print(x_valid.shape)
print(y_valid.shape)
print(x_test.shape)
# Out:
# (50000, 96, 96, 3)
# (50000, 1)
# (32768, 96, 96, 3)
# (32768, 1)
# (32768, 96, 96, 3)

# %%
classes = ['正常','腫瘍']

for i in range(5):
    print(classes[y_train[i, 0]])
    plt.imshow(x_train[i])
    plt.show()
    print()
# Out:
# 正常
# 腫瘍
# 腫瘍
# 腫瘍
# 正常

# %%
classes = ['正常','腫瘍']

for i in range(5):
    print(classes[y_valid[i, 0]])
    plt.imshow(x_valid[i])
    plt.show()
    print()
# Out:
# 腫瘍
# 腫瘍
# 腫瘍
# 腫瘍
# 腫瘍

# %%
for i in range(5):
    plt.imshow(x_test[i])
    plt.show()
    print()

# %%
np.sum(y_train[:30000])/30000
# Out:
# np.float64(0.5011)
